# %%
# %matplotlib inline
# Khai bao cac thu vien ho tro
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
print("pandas.__version__ = ", pd.__version__)
# Out:
# pandas.__version__ =  0.23.0

# %%
# Tao dataframe
# B1: Dinh nghia cac thuoc tinh tinh luong cho nhan su gom:
# * Cac thuoc tinh khong anh huong luong: ID, họ tên, địa chỉ, dân tộc, so thich khong lien quan cong viec
# * Cac thuoc tinh anh huong luong: 
# 1. Bang cap: Loai bang, xep loai, truong dao tao
# 2. Tuoi
# 3. Gioi tinh
# 4. Muc luong cong ty cu tra
# 5. Mang cong viec
# 6. So nam kinh nghiem
# 7. So truong trong cong viec: C++, .NET,...
# 8. Do hot cua cong viec hien tai: A, B, C, D
# 9. Ngoai ngu: English(ielst), English(toiec), Tieng Nhat, Tieng Trung, Tieng Phap
# 10. Vi tri ung tuyen: Teamlead
# 11. He so trach nhiem
# 12. Giai thuong, thanh tich ca nhan: olympic tin hoc, khoa hoc sang tao,...
# 13. Nguong luong cho cong viec: Vd: 7tr- 20tr
# 14. Xếp loại trình độ (năng lực công việc) : A, B, C, D 
# (thuộc tính này cho sẵn. Nếu tính thì có thể dựa vào lịch sử kết quả công việc đã đảm nhận)
# 15. Ý thức, trách nhiệm với công việc, công ty
# 16. Thời gian đã gắn bó với công ty
# 17. Luong (Bai toan so 2)
# * Note: Các thuộc tính cần động, tích lũy hoặc thay đổi theo thời gian

# * Tạo phân phối chuẩn
mu, sigma = 0, 5 # mean and standard deviation
s = np.random.normal(mu, sigma, 300)

# * old_company
old_company = 15

# B2: Tao cac list
len_list = 1000
len_list *= 10

# 1. ID
ID = []
for i in range(len_list):
    temp = "FSI_" + str(i)
    ID.append(temp)
#print(ID)

# 2. Tên
Name = [random.choice(['Harry', 'Ron', 'Hermione', 'Luna', 'Long', 'Nam', 'Lan', 'Ngoc']) for i in range(len_list)]
#print(Name)

# 3. Địa chỉ
Dia_chi = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Dia_chi.append('Tinh le')
    else:
        Dia_chi.append('Ha Noi')

# 4. Dân tộc
list_dantoc = ['Thai', 'Mong', 'Tay', 'Nung', 'Muong', 'Dao', 'Hoa', 'Khome', 'Ede', 'Cham']
Dan_toc = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Dan_toc.append('Kinh')
    else:
        temp = random.choice(list_dantoc)
        Dan_toc.append(temp)
               
# 5. Sở thích cá nhân
So_thich_ca_nhan = [random.choice(['Nghe nhac', 'xem phim', 'Cau ca', 'Da bong', 'Cau long', 'Gym', 'Yoga']) for i in range(len_list)]
#print(So_thich_ca_nhan)

# 6. Tuổi
Tuoi = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp<=3):
        temp = random.randrange(18, 30, 1)
        Tuoi.append(temp)
    elif(temp>3 and temp<=8):
        temp = random.randrange(30, 40,1)
        Tuoi.append(temp)
    elif(temp>8 and temp<=10):
        temp = random.randrange(40, 50, 1)
        Tuoi.append(temp)
    else:
        temp = random.randrange(50, 60, 1)
        Tuoi.append(temp)

# 7. Giới tính
Gioi_tinh = [random.choice(['Nam', 'Nu']) for i in range(len_list)]

# 8. Chứng chỉ ngoại ngữ
Ngoai_ngu = []
list_language = ['Tieng anh ielts', 'Tieng Nhat', 'Tieng Trung', 'Tieng Phap', 'Tieng Nga']
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 0):
        Ngoai_ngu.append('Khong chung chi')
    elif(temp>0 and temp<=5):
        Ngoai_ngu.append('Tieng anh toiec')
    else:
        temp = random.choice(list_language)
        Ngoai_ngu.append(temp)

        
# 9. Ý thức trách nhiệm với công việc công ty
Y_thuc_trach_nhiem = [random.choice(['A', 'B', 'C', 'D']) for i in range(len_list)]


# 11, 12, 13. Thông tin về bằng cấp
list_bang = ['Khong', 'Dai hoc', 'Thac si', 'Tien si']
list_truong = ['HNUE', 'HUST', 'EPU', 'VNU', 'USTH', 'HAUI', 'UTC', 'TLU']
Bang_cap = []
Xep_loai_bang = []
Truong_dao_tao = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp<=0):
        bang = random.choice(['Dai hoc', 'Cao dang']);
        Bang_cap.append(bang)
    elif(temp>8):
        if(Tuoi[i] > 27 and Ngoai_ngu[i] != 'Khong chung chi'):
            bang = random.choice(['Thac si', 'Tien si'])
            Bang_cap.append(bang)
        else:
            bang = 'Thac si'
            Bang_cap.append(bang)
    else:
        bang = random.choice(['Dai hoc', 'Cao dang', 'Khong bang cap'])
        Bang_cap.append(bang)
        
    # Khong co bang cap, hoac la bang TS se khong co xep loai
    if(bang == 'Khong bang cap' or bang == 'Tien si'):
        Xep_loai_bang.append('Khong xep loai')
    else:
        Xep_loai_bang.append(random.choice(['Trung binh', 'kha', 'Gioi', 'Xuat sac']))
        
        
    if(bang == 'Khong bang cap'):
        Truong_dao_tao.append('Khong di hoc')
    else:
        temp = random.choice(list_truong)
        Truong_dao_tao.append(temp)

        
# 14. Mảng công việc
Mang_cong_viec = []
for i in range(len_list):
    temp = random.choice(s)
    if(Bang_cap[i] == 'Tien si'):
        Mang_cong_viec.append('Ky su R&D')
    else:
        if(temp <= 0):
            Mang_cong_viec.append('Lap trinh vien')
        elif(temp>0 and temp<=5):
            viec = random.choice(['Ky su R&D', 'BA', 'Tu van ban hang'])
            Mang_cong_viec.append(viec)
        else:
            if(Gioi_tinh[i] == 'Nam'):
                Mang_cong_viec.append('PM')
            else:
                viec = random.choice(['Ke toan', 'Tester', 'Xu ly data'])
                Mang_cong_viec.append(viec)
            
            

# 15. Số năm kinh nghiệm
Nam_kinh_nghiem = []
for i in range(len_list):
    temp = Tuoi[i] - 18;
    if(temp > 0):
        kn = random.randrange(0, temp, 1)
        #print('type = ', type(temp))
        Nam_kinh_nghiem.append(kn)
    else:
        Nam_kinh_nghiem.append(0)
    #print('Nam_kinh_nghiem = ', Nam_kinh_nghiem[i])

# 16. Sở trường công việc
So_truong = []
for i in range(len_list):
    if(Mang_cong_viec[i] == 'Lap trinh vien'):
        temp = random.choice(['C++', '.NET', 'Java', 'Android', 'Ruby', 'PHP', 'Python', 'ios'])
        So_truong.append(temp)
    elif(Mang_cong_viec[i] == 'Ky su R&D'):
        temp = random.choice(['Computer vision', 'NLP', 'Data Science', 'Tools'])
        So_truong.append(temp)
    else:
        So_truong.append('None')

# 10. Mức độ hót của công việc hiện tại
Hot_work = []
for i in range(len_list):
    if(So_truong[i] == 'C++' or So_truong[i] == 'Java' or So_truong[i] == 'ios'):
        Hot_work.append('A')
    elif(So_truong[i] == 'PHP'):
        Hot_work.append('C')
    elif(So_truong[i]=='None'):
        Hot_work.append('D')
    else:
        Hot_work.append('B')

# 17. Vị trí ứng tuyển
Vi_tri = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp < 5):
        Vi_tri.append('Nhan vien')
    else:
        if(Nam_kinh_nghiem[i]>8):
            Vi_tri.append(random.choice(['Technical leader', 'Truong phong']))
        else:
            Vi_tri.append('Teamlead')
    

# 18. Hệ số trách nhiệm
He_so_trach_nhiem = []
for i in range(len_list):
    if(Vi_tri[i] == 'Nhan vien'):
        He_so_trach_nhiem.append(1)
    elif(Vi_tri[i] == 'Teamlead'):
        He_so_trach_nhiem.append(1.5)
    elif(Vi_tri[i] == 'Teachnical leader'):
        He_so_trach_nhiem.append(2)
    elif(Vi_tri[i] == 'Truong phong'):
        He_so_trach_nhiem.append(4)
    else:
        He_so_trach_nhiem.append(1)
        
# 19. Giải thưởng, thành tích cá nhân
Thanh_tich = []
list_thanhtich = ['Oympic toan', 'olympic tin', 'Khoa hoc sang tao', 'Nhan tai dat viet', 'None']
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Thanh_tich.append('None')
    else:
        
        if(Bang_cap[i] == 'Khong'):
            Thanh_tich.append('None')
        else:
            temp = random.choice(list_thanhtich)
            Thanh_tich.append(temp)
# 20. Ngưỡng lương
Nguong_luong = []
for i in range(len_list):
    if(Mang_cong_viec[i] == 'PM'):
        Nguong_luong.append(30)
    elif(Mang_cong_viec[i] == 'Lap trinh vien' or Mang_cong_viec[i] == 'Ky su R&D' or Mang_cong_viec[i] == 'BA'):
        Nguong_luong.append(25)
    else:
        Nguong_luong.append(15)
        
# 21. Xep loai trinh do (Nang luc thuc hien cong viec)
Nang_luc_work = []
for i in range(len_list):
    if(Bang_cap[i]=='Thac si' or Bang_cap[i] == 'Tien si' or Vi_tri[i]=='Truong phong' or Vi_tri[i]== 'Technical leader'):
        temp = random.choice(s)
        if(temp < 5):
            Nang_luc_work.append(random.choice(['A']))
        else:
            Nang_luc_work.append(random.choice(['A', 'B']))
    else:
        Nang_luc_work.append(random.choice(['A', 'B', 'C', 'D']))

# 22. Thời gian gắn bó với công ty
Thoi_gian_gan_bo = []
for i in range(len_list):
    temp = random.choice(s)
    time_max = Tuoi[i] - 18
    if(Tuoi[i] <=19):
        if(temp>=0):
            Thoi_gian_gan_bo.append(0)
        else:
            Thoi_gian_gan_bo.append(1)
    else:
        if(time_max >= old_company):
            Thoi_gian_gan_bo.append(random.randrange(0, old_company, 1))
        else:
            Thoi_gian_gan_bo.append(random.randrange(0, time_max, 1))
        
# 23. Lịch sử lương
Luong_cu = []
for i in range(len_list):
    if(Bang_cap[i] == 'Tien si'):
        money_min = 20
    elif(Bang_cap[i] == 'Thac si'):
        money_min = 15
    elif(Bang_cap[i] == 'Dai hoc '):
        money_min = 7
    else:
        money_min = 4
        
    if(money_min < Nguong_luong[i]):
        temp = random.randrange(money_min, Nguong_luong[i], 1) * He_so_trach_nhiem[i]
        Luong_cu.append(temp)
    else:
        temp = money_min * He_so_trach_nhiem[i]
        Luong_cu.append(temp)
    

# 24. Lương
# Lương mô phỏng phụ thuộc 5 features: Mảng công việc, bằng cấp, số năm kinh nghiệm, vị trí ứng tuyển, năng lực công việc.
Luong = []
for i in range(len_list):
    # 24.1 Ban đầu ước lượng theo mảng công việc
    if(Mang_cong_viec[i] == 'Ke toan' or Mang_cong_viec[i] == 'Xu ly data'):
        base = 4.2
    else:
        base = 7
    
    # 24.2 Xét theo bằng cấp: nếu bằng thạc sĩ ko thấp hơn 10tr, tiến sĩ ko thấp hơn 15tr, các loại khác để nguyên
    if(Bang_cap[i] == 'Thac si'):
        base = 10
    if(Bang_cap[i] == 'Tien si'):
        base = 15
    
    # 24.3 Xét tiếp theo năm kinh nghiệm: 
    # dưới 1 năm kinh nghiệm thì giữ nguyên mức cơ bản
    # 1-3 năm tăng 30% cơ bản
    # 3-5 năm tăng 50% bản
    # Trên 5 năm kinh nghiệm tăng 100% lương
    if(Nam_kinh_nghiem[i]<= 1):
        luong = base
    elif(Nam_kinh_nghiem[i] > 1 and Nam_kinh_nghiem[i]<=3):
        luong = base + base * 0.3
    elif(Nam_kinh_nghiem[i] > 3 and Nam_kinh_nghiem[i]<=5):
        luong = base + base * 0.5
    elif(Nam_kinh_nghiem[i] > 5):
        luong = base * 2
        
    # 24.4 Xét tiếp theo vị trí:
    # Nhân viên: giữ nguyên
    # Leader tăng 150%
    # Teachnical tăng 180%
    # Trưởng phòng tăng 300%
    if(Vi_tri[i] == 'Nhan vien'):
        luong = luong
    elif(Vi_tri[i] == 'Team leader'):
        luong = luong + luong * 0.5
    elif(Vi_tri[i] == 'Technical leader'):
        luong = luong + luong * 0.8
    elif(Vi_tri[i] == 'Truong phong'):
        luong = luong * 3
    
    # 24.5 Xét tiếp theo năng lực
    # Năng lực mức C là bình thường, giữ nguyên
    # Năng lực mức B thêm 2 triệu
    # Năng lực mức A thêm 5 triệu
    # Năng lực mức D kém hơn bình thường, giảm 2 triệu
    if(Nang_luc_work[i] == "C"):
        luong = luong
    elif(Nang_luc_work[i] == "B"):
        luong = luong + 2
    elif(Nang_luc_work[i] == "A"):
        luong = luong + 5
    elif(Nang_luc_work[i] == "D"):
        luong = luong - 2
        
    Luong.append(luong)
        
# B3: Tao dataframe
calculary_salary = pd.DataFrame()
calculary_salary['ID'] = ID
calculary_salary['Name'] = Name
calculary_salary['Dia_chi'] = Dia_chi
calculary_salary['Dan_toc'] = Dan_toc
calculary_salary['So_thich_ca_nhan'] = So_thich_ca_nhan
calculary_salary['Tuoi'] = Tuoi
calculary_salary['Gioi_tinh'] = Gioi_tinh
calculary_salary['Ngoai_ngu'] = Ngoai_ngu
calculary_salary['Y_thuc_trach_nhiem'] = Y_thuc_trach_nhiem
calculary_salary['Hot_work'] = Hot_work

calculary_salary['Bang_cap'] = Bang_cap
calculary_salary['Xep_loai_bang'] = Xep_loai_bang
calculary_salary['Truong_dao_tao'] = Truong_dao_tao

calculary_salary['Mang_cong_viec'] = Mang_cong_viec
calculary_salary['Nam_kinh_nghiem'] = Nam_kinh_nghiem
calculary_salary['So_truong'] = So_truong
calculary_salary['Vi_tri'] = Vi_tri
calculary_salary['He_so_trach_nhiem'] = He_so_trach_nhiem
calculary_salary['Thanh_tich'] = Thanh_tich
calculary_salary['Nguong_luong'] = Nguong_luong
calculary_salary['Nang_luc_work'] = Nang_luc_work
calculary_salary['Thoi_gian_gan_bo'] = Thoi_gian_gan_bo
calculary_salary['Luong_cu'] = Luong_cu

calculary_salary['Luong'] = Luong

# B4: Luu DataFrame
calculary_salary.to_csv('calculary_salary.csv')

print("DONE")
# Out:
# DONE

# %%
# Xem thử 100 bản ghi
calculary_salary.head(100)
# Out:
#         ID      Name  Dia_chi Dan_toc So_thich_ca_nhan  Tuoi Gioi_tinh  \
# 0    FSI_0      Long   Ha Noi    Cham        Nghe nhac    20        Nu
# 1    FSI_1       Nam   Ha Noi    Kinh              Gym    27       Nam
# 2    FSI_2       Lan  Tinh le    Kinh             Yoga    23       Nam
# 3    FSI_3       Ron  Tinh le    Kinh         xem phim    26       Nam
# 4    FSI_4     Harry  Tinh le    Kinh         Cau long    33        Nu
# 5    FSI_5     Harry  Tinh le    Kinh          Da bong    36       Nam
# 6    FSI_6      Luna  Tinh le    Kinh          Da bong    21       Nam
# 7    FSI_7     Harry   Ha Noi    Kinh         xem phim    23       Nam
# 8    FSI_8      Ngoc  Tinh le    Kinh             Yoga    18       Nam
# 9    FSI_9       Ron  Tinh le    Kinh         Cau long    39        Nu
# 10  FSI_10  Hermione  Tinh le    Kinh          Da bong    31       Nam
# 11  FSI_11     Harry  Tinh le    Kinh           Cau ca    33        Nu
# 12  FSI_12      Luna  Tinh le    Kinh        Nghe nhac    23        Nu
# 13  FSI_13      Long  Tinh le    Kinh          Da bong    38       Nam
# 14  FSI_14       Ron  Tinh le    Kinh        Nghe nhac    29        Nu
# 15  FSI_15       Nam  Tinh le    Kinh          Da bong    28       Nam
# 16  FSI_16  Hermione  Tinh le    Kinh         xem phim    38        Nu
# 17  FSI_17      Luna  Tinh le    Kinh             Yoga    28        Nu
# 18  FSI_18      Ngoc  Tinh le     Dao         xem phim    18        Nu
# 19  FSI_19       Ron  Tinh le    Kinh              Gym    24       Nam
# 20  FSI_20      Ngoc  Tinh le    Kinh        Nghe nhac    23       Nam
# 21  FSI_21       Nam  Tinh le    Kinh          Da bong    34       Nam
# 22  FSI_22      Luna  Tinh le    Kinh         xem phim    29        Nu
# 23  FSI_23      Long  Tinh le   Khome        Nghe nhac    29        Nu
# 24  FSI_24      Luna  Tinh le    Kinh             Yoga    28        Nu
# 25  FSI_25      Ngoc  Tinh le    Kinh           Cau ca    21       Nam
# 26  FSI_26       Nam  Tinh le    Kinh             Yoga    30       Nam
# 27  FSI_27      Long  Tinh le    Kinh             Yoga    22       Nam
# 28  FSI_28       Ron  Tinh le   Khome         xem phim    22       Nam
# 29  FSI_29  Hermione  Tinh le     Hoa           Cau ca    18        Nu
# ..     ...       ...      ...     ...              ...   ...       ...
# 70  FSI_70      Long  Tinh le    Kinh          Da bong    22       Nam
# 71  FSI_71      Luna  Tinh le    Kinh          Da bong    29       Nam
# 72  FSI_72      Long  Tinh le    Kinh           Cau ca    22        Nu
# 73  FSI_73     Harry  Tinh le    Kinh        Nghe nhac    21       Nam
# 74  FSI_74  Hermione  Tinh le    Kinh           Cau ca    18        Nu
# 75  FSI_75  Hermione   Ha Noi     Ede         Cau long    22       Nam
# 76  FSI_76       Lan  Tinh le    Kinh         xem phim    31       Nam
# 77  FSI_77  Hermione   Ha Noi    Kinh              Gym    28        Nu
# 78  FSI_78       Nam  Tinh le    Kinh           Cau ca    47        Nu
# 79  FSI_79     Harry   Ha Noi    Kinh          Da bong    29        Nu
# 80  FSI_80     Harry  Tinh le    Kinh         Cau long    29        Nu
# 81  FSI_81      Long   Ha Noi    Kinh         Cau long    24       Nam
# 82  FSI_82       Lan  Tinh le    Kinh          Da bong    36        Nu
# 83  FSI_83      Long  Tinh le    Kinh          Da bong    20       Nam
# 84  FSI_84       Lan  Tinh le    Kinh          Da bong    20       Nam
# 85  FSI_85  Hermione  Tinh le    Kinh         xem phim    18        Nu
# 86  FSI_86       Nam  Tinh le    Kinh        Nghe nhac    28       Nam
# 87  FSI_87     Harry  Tinh le    Kinh         Cau long    28       Nam
# 88  FSI_88      Luna  Tinh le    Kinh          Da bong    37        Nu
# 89  FSI_89      Long   Ha Noi    Cham          Da bong    37       Nam
# 90  FSI_90       Nam  Tinh le    Kinh         Cau long    18       Nam
# 91  FSI_91  Hermione  Tinh le    Cham           Cau ca    20       Nam
# 92  FSI_92     Harry  Tinh le    Kinh         xem phim    23       Nam
# 93  FSI_93      Luna   Ha Noi    Kinh             Yoga    25        Nu
# 94  FSI_94  Hermione  Tinh le    Kinh             Yoga    27       Nam
# 95  FSI_95      Ngoc  Tinh le   Khome        Nghe nhac    24       Nam
# 96  FSI_96      Ngoc  Tinh le    Kinh         Cau long    21       Nam
# 97  FSI_97     Harry  Tinh le    Kinh        Nghe nhac    21        Nu
# 98  FSI_98       Lan  Tinh le    Kinh          Da bong    25       Nam
# 99  FSI_99      Ngoc  Tinh le    Kinh             Yoga    25        Nu
#
#           Ngoai_ngu Y_thuc_trach_nhiem Hot_work  ...   Nam_kinh_nghiem  \
# 0   Khong chung chi                  A        D  ...                 0
# 1   Khong chung chi                  C        B  ...                 2
# 2   Khong chung chi                  A        A  ...                 4
# 3   Khong chung chi                  A        B  ...                 5
# 4   Khong chung chi                  A        D  ...                 6
# 5   Tieng anh toiec                  A        D  ...                15
# 6        Tieng Nhat                  C        B  ...                 2
# 7   Tieng anh toiec                  D        A  ...                 4
# 8   Khong chung chi                  A        A  ...                 0
# 9   Khong chung chi                  C        B  ...                20
# 10  Khong chung chi                  D        B  ...                 6
# 11  Khong chung chi                  B        A  ...                 6
# 12  Tieng anh toiec                  C        C  ...                 0
# 13  Tieng anh toiec                  B        A  ...                14
# 14  Khong chung chi                  A        A  ...                 9
# 15  Tieng anh ielts                  C        A  ...                 7
# 16  Khong chung chi                  D        B  ...                16
# 17  Khong chung chi                  C        D  ...                 1
# 18  Khong chung chi                  B        B  ...                 0
# 19  Khong chung chi                  B        B  ...                 4
# 20  Tieng anh toiec                  D        D  ...                 0
# 21  Tieng anh toiec                  A        B  ...                 1
# 22        Tieng Nga                  A        C  ...                 4
# 23  Tieng anh toiec                  D        B  ...                 1
# 24  Khong chung chi                  D        B  ...                 3
# 25  Khong chung chi                  C        D  ...                 2
# 26  Tieng anh toiec                  A        B  ...                 4
# 27  Tieng anh toiec                  C        D  ...                 1
# 28  Khong chung chi                  C        B  ...                 0
# 29       Tieng Nhat                  B        D  ...                 0
# ..              ...                ...      ...  ...               ...
# 70  Khong chung chi                  A        A  ...                 2
# 71  Tieng anh toiec                  A        A  ...                 6
# 72  Khong chung chi                  B        B  ...                 0
# 73  Khong chung chi                  D        B  ...                 2
# 74  Khong chung chi                  C        D  ...                 0
# 75  Tieng anh toiec                  B        C  ...                 1
# 76  Tieng anh toiec                  B        B  ...                 4
# 77  Khong chung chi                  C        D  ...                 2
# 78  Tieng anh toiec                  B        B  ...                 5
# 79  Khong chung chi                  B        D  ...                 1
# 80  Khong chung chi                  B        D  ...                 6
# 81  Tieng anh ielts                  D        D  ...                 1
# 82  Tieng anh toiec                  B        D  ...                 0
# 83  Khong chung chi                  B        D  ...                 0
# 84  Khong chung chi                  D        B  ...                 0
# 85  Tieng anh toiec                  C        D  ...                 0
# 86  Tieng anh toiec                  D        A  ...                 1
# 87  Tieng anh toiec                  C        D  ...                 8
# 88  Khong chung chi                  D        B  ...                 7
# 89  Khong chung chi                  B        D  ...                17
# 90  Tieng anh toiec                  C        D  ...                 0
# 91  Khong chung chi                  D        B  ...                 0
# 92  Khong chung chi                  A        D  ...                 2
# 93  Khong chung chi                  C        D  ...                 5
# 94        Tieng Nga                  D        B  ...                 7
# 95  Khong chung chi                  B        D  ...                 0
# 96  Khong chung chi                  B        D  ...                 0
# 97  Khong chung chi                  A        B  ...                 1
# 98  Tieng anh toiec                  B        B  ...                 3
# 99  Tieng anh toiec                  A        B  ...                 1
#
#           So_truong     Vi_tri He_so_trach_nhiem         Thanh_tich  \
# 0              None  Nhan vien               1.0        olympic tin
# 1           Android  Nhan vien               1.0               None
# 2              Java  Nhan vien               1.0               None
# 3           Android  Nhan vien               1.0               None
# 4              None   Teamlead               1.5               None
# 5              None  Nhan vien               1.0               None
# 6            Python   Teamlead               1.5               None
# 7               C++  Nhan vien               1.0               None
# 8              Java  Nhan vien               1.0               None
# 9              Ruby  Nhan vien               1.0               None
# 10     Data Science   Teamlead               1.5        olympic tin
# 11              ios  Nhan vien               1.0               None
# 12              PHP  Nhan vien               1.0               None
# 13             Java  Nhan vien               1.0               None
# 14              C++  Nhan vien               1.0               None
# 15              ios  Nhan vien               1.0               None
# 16             Ruby  Nhan vien               1.0               None
# 17             None  Nhan vien               1.0               None
# 18          Android  Nhan vien               1.0               None
# 19             Ruby  Nhan vien               1.0               None
# 20             None  Nhan vien               1.0               None
# 21             .NET  Nhan vien               1.0        Oympic toan
# 22              PHP  Nhan vien               1.0               None
# 23          Android  Nhan vien               1.0               None
# 24     Data Science  Nhan vien               1.0               None
# 25             None  Nhan vien               1.0               None
# 26              NLP  Nhan vien               1.0               None
# 27             None  Nhan vien               1.0               None
# 28             Ruby  Nhan vien               1.0               None
# 29             None  Nhan vien               1.0               None
# ..              ...        ...               ...                ...
# 70             Java   Teamlead               1.5               None
# 71              ios   Teamlead               1.5               None
# 72           Python  Nhan vien               1.0               None
# 73  Computer vision  Nhan vien               1.0               None
# 74             None  Nhan vien               1.0               None
# 75              PHP  Nhan vien               1.0               None
# 76             .NET  Nhan vien               1.0               None
# 77             None  Nhan vien               1.0               None
# 78             Ruby  Nhan vien               1.0               None
# 79             None  Nhan vien               1.0               None
# 80             None  Nhan vien               1.0               None
# 81             None  Nhan vien               1.0               None
# 82             None   Teamlead               1.5               None
# 83             None  Nhan vien               1.0               None
# 84     Data Science  Nhan vien               1.0               None
# 85             None  Nhan vien               1.0  Khoa hoc sang tao
# 86              ios  Nhan vien               1.0               None
# 87             None  Nhan vien               1.0               None
# 88  Computer vision   Teamlead               1.5               None
# 89             None  Nhan vien               1.0               None
# 90             None  Nhan vien               1.0               None
# 91             .NET  Nhan vien               1.0               None
# 92             None  Nhan vien               1.0               None
# 93             None  Nhan vien               1.0               None
# 94           Python  Nhan vien               1.0               None
# 95             None  Nhan vien               1.0               None
# 96             None  Nhan vien               1.0               None
# 97              NLP  Nhan vien               1.0               None
# 98              NLP  Nhan vien               1.0               None
# 99          Android  Nhan vien               1.0               None
#
#    Nguong_luong Nang_luc_work  Thoi_gian_gan_bo Luong_cu  Luong
# 0            25             C                 0     24.0    7.0
# 1            25             B                 8     16.0   11.1
# 2            25             B                 4      7.0   12.5
# 3            25             D                 4     18.0    8.5
# 4            15             B                 7     15.0   16.0
# 5            15             A                 9      4.0   19.0
# 6            25             A                 2     36.0   18.0
# 7            25             D                 3     11.0    8.5
# 8            25             D                 1     11.0    5.0
# 9            25             C                 1     11.0   14.0
# 10           25             B                 9     15.0   16.0
# 11           25             D                 9      6.0   12.0
# 12           25             A                 2     23.0   12.0
# 13           25             B                 0     12.0   16.0
# 14           25             B                 8      7.0   16.0
# 15           25             D                 5     22.0   12.0
# 16           25             D                10     22.0   12.0
# 17           15             C                 2     12.0    7.0
# 18           25             D                 0      5.0    5.0
# 19           25             C                 5     12.0   10.5
# 20           30             D                 1     20.0    5.0
# 21           25             A                 8      8.0   12.0
# 22           25             B                 4     21.0   12.5
# 23           25             C                 2     18.0    7.0
# 24           25             D                 7      5.0    7.1
# 25           30             A                 0     27.0   14.1
# 26           25             A                 7     22.0   15.5
# 27           25             B                 2      7.0    9.0
# 28           25             D                 0     17.0    5.0
# 29           15             B                 0     11.0    6.2
# ..          ...           ...               ...      ...    ...
# 70           25             A                 3     27.0   18.0
# 71           25             B                 3     16.5   16.0
# 72           25             D                 1      5.0    5.0
# 73           25             B                 2     11.0   11.1
# 74           15             C                 0     11.0    4.2
# 75           25             D                 1      5.0    5.0
# 76           25             A                12     14.0   15.5
# 77           15             A                 6      4.0   14.1
# 78           25             B                 8      7.0   12.5
# 79           15             A                 4     14.0   12.0
# 80           15             C                 8      4.0   14.0
# 81           15             C                 2      8.0    7.0
# 82           25             B                14     34.5    9.0
# 83           15             D                 0      4.0    5.0
# 84           25             B                 1      9.0    9.0
# 85           15             D                 0      7.0    2.2
# 86           25             B                 8      9.0    9.0
# 87           15             C                 9      7.0   14.0
# 88           25             A                 8     13.5   19.0
# 89           25             B                13      9.0   16.0
# 90           15             B                 0      4.0    9.0
# 91           25             C                 0      9.0    7.0
# 92           30             D                 3     21.0    7.1
# 93           15             C                 3     11.0   10.5
# 94           25             A                 0     15.0   19.0
# 95           15             A                 5      5.0   12.0
# 96           30             D                 1     23.0    5.0
# 97           25             D                 2     21.0    5.0
# 98           25             C                 6     17.0    9.1
# 99           25             C                 6     20.0    7.0
#
# [100 rows x 24 columns]

# %%
# Thống kê cơ bản
calculary_salary.describe()
# Out:
#                Tuoi  Nam_kinh_nghiem  He_so_trach_nhiem  Nguong_luong  \
# count  10000.000000     10000.000000       10000.000000  10000.000000
# mean      26.995000         4.079000           1.091250     23.616000
# std        7.735526         5.173668           0.336244      4.187636
# min       18.000000         0.000000           1.000000     15.000000
# 25%       21.000000         0.000000           1.000000     25.000000
# 50%       26.000000         2.000000           1.000000     25.000000
# 75%       29.000000         6.000000           1.000000     25.000000
# max       59.000000        39.000000           4.000000     30.000000
#
#        Thoi_gian_gan_bo      Luong_cu         Luong
# count      10000.000000  10000.000000  10000.000000
# mean           3.465300     14.884700     11.714086
# std            3.537803      8.468907      5.947426
# min            0.000000      4.000000      2.200000
# 25%            1.000000      9.000000      7.460000
# 50%            2.000000     14.000000     11.100000
# 75%            5.000000     20.000000     14.100000
# max           14.000000    112.000000     65.000000

# %%
# Số lượng giá trị của một trường dữ liệu
calculary_salary['Bang_cap'].value_counts()
# Out:
# Cao dang          4087
# Dai hoc           4002
# Khong bang cap    1394
# Thac si            471
# Tien si             46
# Name: Bang_cap, dtype: int64

# %%
# Vẽ đồ thị xem phân bố các trường dữ liệu
calculary_salary['Vi_tri'].value_counts().plot(kind='bar')
