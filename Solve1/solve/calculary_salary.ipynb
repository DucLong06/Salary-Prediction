# %%
# %matplotlib inline
# Khai bao cac thu vien ho tro
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
print("pandas.__version__ = ", pd.__version__)
# Out:
# pandas.__version__ =  0.23.0

# %%
# Tao dataframe
# B1: Dinh nghia cac thuoc tinh tinh luong cho nhan su gom:
# * Cac thuoc tinh khong anh huong luong: ID, họ tên, địa chỉ, dân tộc, so thich khong lien quan cong viec
# * Cac thuoc tinh anh huong luong: 
# 1. Bang cap: Loai bang, xep loai, truong dao tao
# 2. Tuoi
# 3. Gioi tinh
# 4. Muc luong cong ty cu tra
# 5. Mang cong viec
# 6. So nam kinh nghiem
# 7. So truong trong cong viec: C++, .NET,...
# 8. Do hot cua cong viec hien tai: A, B, C, D
# 9. Ngoai ngu: English(ielst), English(toiec), Tieng Nhat, Tieng Trung, Tieng Phap
# 10. Vi tri ung tuyen: Teamlead
# 11. He so trach nhiem
# 12. Giai thuong, thanh tich ca nhan: olympic tin hoc, khoa hoc sang tao,...
# 13. Nguong luong cho cong viec: Vd: 7tr- 20tr
# 14. Xếp loại trình độ (năng lực công việc) : A, B, C, D 
# (thuộc tính này cho sẵn. Nếu tính thì có thể dựa vào lịch sử kết quả công việc đã đảm nhận)
# 15. Ý thức, trách nhiệm với công việc, công ty
# 16. Thời gian đã gắn bó với công ty
# 17. Luong (Bai toan so 2)
# * Note: Các thuộc tính cần động, tích lũy hoặc thay đổi theo thời gian

# * Tạo phân phối chuẩn
mu, sigma = 0, 5 # mean and standard deviation
s = np.random.normal(mu, sigma, 300)

# * old_company
old_company = 15

# B2: Tao cac list
len_list = 1000
len_list *= 10

# 1. ID
ID = []
for i in range(len_list):
    temp = "FSI_" + str(i)
    ID.append(temp)
#print(ID)

# 2. Tên
Name = [random.choice(['Harry', 'Ron', 'Hermione', 'Luna', 'Long', 'Nam', 'Lan', 'Ngoc']) for i in range(len_list)]
#print(Name)

# 3. Địa chỉ
Dia_chi = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Dia_chi.append('Tinh le')
    else:
        Dia_chi.append('Ha Noi')

# 4. Dân tộc
list_dantoc = ['Thai', 'Mong', 'Tay', 'Nung', 'Muong', 'Dao', 'Hoa', 'Khome', 'Ede', 'Cham']
Dan_toc = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Dan_toc.append('Kinh')
    else:
        temp = random.choice(list_dantoc)
        Dan_toc.append(temp)
               
# 5. Sở thích cá nhân
So_thich_ca_nhan = [random.choice(['Nghe nhac', 'xem phim', 'Cau ca', 'Da bong', 'Cau long', 'Gym', 'Yoga']) for i in range(len_list)]
#print(So_thich_ca_nhan)

# 6. Tuổi
Tuoi = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp<=3):
        temp = random.randrange(18, 30, 1)
        Tuoi.append(temp)
    elif(temp>3 and temp<=8):
        temp = random.randrange(30, 40,1)
        Tuoi.append(temp)
    elif(temp>8 and temp<=10):
        temp = random.randrange(40, 50, 1)
        Tuoi.append(temp)
    else:
        temp = random.randrange(50, 60, 1)
        Tuoi.append(temp)

# 7. Giới tính
Gioi_tinh = [random.choice(['Nam', 'Nu']) for i in range(len_list)]

# 8. Chứng chỉ ngoại ngữ
Ngoai_ngu = []
list_language = ['Tieng anh ielts', 'Tieng Nhat', 'Tieng Trung', 'Tieng Phap', 'Tieng Nga']
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 0):
        Ngoai_ngu.append('Khong chung chi')
    elif(temp>0 and temp<=5):
        Ngoai_ngu.append('Tieng anh toiec')
    else:
        temp = random.choice(list_language)
        Ngoai_ngu.append(temp)

        
# 9. Ý thức trách nhiệm với công việc công ty
Y_thuc_trach_nhiem = [random.choice(['A', 'B', 'C', 'D']) for i in range(len_list)]


# 11, 12, 13. Thông tin về bằng cấp
list_bang = ['Khong', 'Dai hoc', 'Thac si', 'Tien si']
list_truong = ['HNUE', 'HUST', 'EPU', 'VNU', 'USTH', 'HAUI', 'UTC', 'TLU']
Bang_cap = []
Xep_loai_bang = []
Truong_dao_tao = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp<=0):
        bang = random.choice(['Dai hoc', 'Cao dang']);
        Bang_cap.append(bang)
    elif(temp>8):
        if(Tuoi[i] > 27 and Ngoai_ngu[i] != 'Khong chung chi'):
            bang = random.choice(['Thac si', 'Tien si'])
            Bang_cap.append(bang)
        else:
            bang = 'Thac si'
            Bang_cap.append(bang)
    else:
        bang = random.choice(['Dai hoc', 'Cao dang', 'Khong bang cap'])
        Bang_cap.append(bang)
        
    # Khong co bang cap, hoac la bang TS se khong co xep loai
    if(bang == 'Khong bang cap' or bang == 'Tien si'):
        Xep_loai_bang.append('Khong xep loai')
    else:
        Xep_loai_bang.append(random.choice(['Trung binh', 'kha', 'Gioi', 'Xuat sac']))
        
        
    if(bang == 'Khong bang cap'):
        Truong_dao_tao.append('Khong di hoc')
    else:
        temp = random.choice(list_truong)
        Truong_dao_tao.append(temp)

        
# 14. Mảng công việc
Mang_cong_viec = []
for i in range(len_list):
    temp = random.choice(s)
    if(Bang_cap[i] == 'Tien si'):
        Mang_cong_viec.append('Ky su R&D')
    else:
        if(temp <= 0):
            Mang_cong_viec.append('Lap trinh vien')
        elif(temp>0 and temp<=5):
            viec = random.choice(['Ky su R&D', 'BA', 'Tu van ban hang'])
            Mang_cong_viec.append(viec)
        else:
            if(Gioi_tinh[i] == 'Nam'):
                Mang_cong_viec.append('PM')
            else:
                viec = random.choice(['Ke toan', 'Tester', 'Xu ly data'])
                Mang_cong_viec.append(viec)
            
            

# 15. Số năm kinh nghiệm
Nam_kinh_nghiem = []
for i in range(len_list):
    temp = Tuoi[i] - 18;
    if(temp > 0):
        kn = random.randrange(0, temp, 1)
        #print('type = ', type(temp))
        Nam_kinh_nghiem.append(kn)
    else:
        Nam_kinh_nghiem.append(0)
    #print('Nam_kinh_nghiem = ', Nam_kinh_nghiem[i])

# 16. Sở trường công việc
So_truong = []
for i in range(len_list):
    if(Mang_cong_viec[i] == 'Lap trinh vien'):
        temp = random.choice(['C++', '.NET', 'Java', 'Android', 'Ruby', 'PHP', 'Python', 'ios'])
        So_truong.append(temp)
    elif(Mang_cong_viec[i] == 'Ky su R&D'):
        temp = random.choice(['Computer vision', 'NLP', 'Data Science', 'Tools'])
        So_truong.append(temp)
    else:
        So_truong.append('None')

# 10. Mức độ hót của công việc hiện tại
Hot_work = []
for i in range(len_list):
    if(So_truong[i] == 'C++' or So_truong[i] == 'Java' or So_truong[i] == 'ios'):
        Hot_work.append('A')
    elif(So_truong[i] == 'PHP'):
        Hot_work.append('C')
    elif(So_truong[i]=='None'):
        Hot_work.append('D')
    else:
        Hot_work.append('B')

# 17. Vị trí ứng tuyển
Vi_tri = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp < 5):
        Vi_tri.append('Nhan vien')
    else:
        if(Nam_kinh_nghiem[i]>8):
            Vi_tri.append(random.choice(['Technical leader', 'Truong phong']))
        else:
            Vi_tri.append('Teamlead')
    

# 18. Hệ số trách nhiệm
He_so_trach_nhiem = []
for i in range(len_list):
    if(Vi_tri[i] == 'Nhan vien'):
        He_so_trach_nhiem.append(1)
    elif(Vi_tri[i] == 'Teamlead'):
        He_so_trach_nhiem.append(1.5)
    elif(Vi_tri[i] == 'Teachnical leader'):
        He_so_trach_nhiem.append(2)
    elif(Vi_tri[i] == 'Truong phong'):
        He_so_trach_nhiem.append(4)
    else:
        He_so_trach_nhiem.append(1)
        
# 19. Giải thưởng, thành tích cá nhân
Thanh_tich = []
list_thanhtich = ['Oympic toan', 'olympic tin', 'Khoa hoc sang tao', 'Nhan tai dat viet', 'None']
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Thanh_tich.append('None')
    else:
        
        if(Bang_cap[i] == 'Khong'):
            Thanh_tich.append('None')
        else:
            temp = random.choice(list_thanhtich)
            Thanh_tich.append(temp)
# 20. Ngưỡng lương
Nguong_luong = []
for i in range(len_list):
    if(Mang_cong_viec[i] == 'PM'):
        Nguong_luong.append(30)
    elif(Mang_cong_viec[i] == 'Lap trinh vien' or Mang_cong_viec[i] == 'Ky su R&D' or Mang_cong_viec[i] == 'BA'):
        Nguong_luong.append(25)
    else:
        Nguong_luong.append(15)
        
# 21. Xep loai trinh do (Nang luc thuc hien cong viec)
Nang_luc_work = []
for i in range(len_list):
    if(Bang_cap[i]=='Thac si' or Bang_cap[i] == 'Tien si' or Vi_tri[i]=='Truong phong' or Vi_tri[i]== 'Technical leader'):
        temp = random.choice(s)
        if(temp < 5):
            Nang_luc_work.append(random.choice(['A']))
        else:
            Nang_luc_work.append(random.choice(['A', 'B']))
    else:
        Nang_luc_work.append(random.choice(['A', 'B', 'C', 'D']))

# 22. Thời gian gắn bó với công ty
Thoi_gian_gan_bo = []
for i in range(len_list):
    temp = random.choice(s)
    time_max = Tuoi[i] - 18
    if(Tuoi[i] <=19):
        if(temp>=0):
            Thoi_gian_gan_bo.append(0)
        else:
            Thoi_gian_gan_bo.append(1)
    else:
        if(time_max >= old_company):
            Thoi_gian_gan_bo.append(random.randrange(0, old_company, 1))
        else:
            Thoi_gian_gan_bo.append(random.randrange(0, time_max, 1))
        
# 23. Lịch sử lương
Luong_cu = []
for i in range(len_list):
    if(Bang_cap[i] == 'Tien si'):
        money_min = 20
    elif(Bang_cap[i] == 'Thac si'):
        money_min = 15
    elif(Bang_cap[i] == 'Dai hoc '):
        money_min = 7
    else:
        money_min = 4
        
    if(money_min < Nguong_luong[i]):
        temp = random.randrange(money_min, Nguong_luong[i], 1) * He_so_trach_nhiem[i]
        Luong_cu.append(temp)
    else:
        temp = money_min * He_so_trach_nhiem[i]
        Luong_cu.append(temp)
    

# 24. Lương
# Lương mô phỏng phụ thuộc 5 features: Mảng công việc, bằng cấp, số năm kinh nghiệm, vị trí ứng tuyển, năng lực công việc.
Luong = []
for i in range(len_list):
    # 24.1 Ban đầu ước lượng theo mảng công việc
    if(Mang_cong_viec[i] == 'Ke toan' or Mang_cong_viec[i] == 'Xu ly data'):
        base = 4.2
    else:
        base = 7
    
    # 24.2 Xét theo bằng cấp: nếu bằng thạc sĩ ko thấp hơn 10tr, tiến sĩ ko thấp hơn 15tr, các loại khác để nguyên
    if(Bang_cap[i] == 'Thac si'):
        base = 10
    if(Bang_cap[i] == 'Tien si'):
        base = 15
    
    # 24.3 Xét tiếp theo năm kinh nghiệm: 
    # dưới 1 năm kinh nghiệm thì giữ nguyên mức cơ bản
    # 1-3 năm tăng 30% cơ bản
    # 3-5 năm tăng 50% bản
    # Trên 5 năm kinh nghiệm tăng 100% lương
    if(Nam_kinh_nghiem[i]<= 1):
        luong = base
    elif(Nam_kinh_nghiem[i] > 1 and Nam_kinh_nghiem[i]<=3):
        luong = base + base * 0.3
    elif(Nam_kinh_nghiem[i] > 3 and Nam_kinh_nghiem[i]<=5):
        luong = base + base * 0.5
    elif(Nam_kinh_nghiem[i] > 5):
        luong = base * 2
        
    # 24.4 Xét tiếp theo vị trí:
    # Nhân viên: giữ nguyên
    # Leader tăng 150%
    # Teachnical tăng 180%
    # Trưởng phòng tăng 300%
    if(Vi_tri[i] == 'Nhan vien'):
        luong = luong
    elif(Vi_tri[i] == 'Team leader'):
        luong = luong + luong * 0.5
    elif(Vi_tri[i] == 'Technical leader'):
        luong = luong + luong * 0.8
    elif(Vi_tri[i] == 'Truong phong'):
        luong = luong * 3
    
    # 24.5 Xét tiếp theo năng lực
    # Năng lực mức C là bình thường, giữ nguyên
    # Năng lực mức B thêm 2 triệu
    # Năng lực mức A thêm 5 triệu
    # Năng lực mức D kém hơn bình thường, giảm 2 triệu
    if(Nang_luc_work[i] == "C"):
        luong = luong
    elif(Nang_luc_work[i] == "B"):
        luong = luong + 2
    elif(Nang_luc_work[i] == "A"):
        luong = luong + 5
    elif(Nang_luc_work[i] == "D"):
        luong = luong - 2
        
    Luong.append(luong)
        
# B3: Tao dataframe
calculary_salary = pd.DataFrame()
calculary_salary['ID'] = ID
calculary_salary['Name'] = Name
calculary_salary['Dia_chi'] = Dia_chi
calculary_salary['Dan_toc'] = Dan_toc
calculary_salary['So_thich_ca_nhan'] = So_thich_ca_nhan
calculary_salary['Tuoi'] = Tuoi
calculary_salary['Gioi_tinh'] = Gioi_tinh
calculary_salary['Ngoai_ngu'] = Ngoai_ngu
calculary_salary['Y_thuc_trach_nhiem'] = Y_thuc_trach_nhiem
calculary_salary['Hot_work'] = Hot_work

calculary_salary['Bang_cap'] = Bang_cap
calculary_salary['Xep_loai_bang'] = Xep_loai_bang
calculary_salary['Truong_dao_tao'] = Truong_dao_tao

calculary_salary['Mang_cong_viec'] = Mang_cong_viec
calculary_salary['Nam_kinh_nghiem'] = Nam_kinh_nghiem
calculary_salary['So_truong'] = So_truong
calculary_salary['Vi_tri'] = Vi_tri
calculary_salary['He_so_trach_nhiem'] = He_so_trach_nhiem
calculary_salary['Thanh_tich'] = Thanh_tich
calculary_salary['Nguong_luong'] = Nguong_luong
calculary_salary['Nang_luc_work'] = Nang_luc_work
calculary_salary['Thoi_gian_gan_bo'] = Thoi_gian_gan_bo
calculary_salary['Luong_cu'] = Luong_cu

calculary_salary['Luong'] = Luong

# B4: Luu DataFrame
calculary_salary.to_csv('calculary_salary.csv')

print("DONE")
# Out:
# DONE

# %%
# Xem thử 100 bản ghi
calculary_salary.head(100)
# Out:
#         ID      Name  Dia_chi Dan_toc So_thich_ca_nhan  Tuoi Gioi_tinh  \
# 0    FSI_0       Nam  Tinh le    Kinh             Yoga    34       Nam
# 1    FSI_1     Harry   Ha Noi    Kinh        Nghe nhac    21       Nam
# 2    FSI_2      Long  Tinh le    Kinh          Da bong    18       Nam
# 3    FSI_3  Hermione  Tinh le    Kinh           Cau ca    23       Nam
# 4    FSI_4      Long  Tinh le    Kinh         Cau long    21        Nu
# 5    FSI_5      Long  Tinh le    Kinh         xem phim    35       Nam
# 6    FSI_6      Ngoc  Tinh le    Kinh             Yoga    19       Nam
# 7    FSI_7       Lan  Tinh le    Kinh              Gym    37        Nu
# 8    FSI_8      Ngoc  Tinh le    Cham         Cau long    22       Nam
# 9    FSI_9      Luna  Tinh le    Kinh             Yoga    28        Nu
# 10  FSI_10     Harry  Tinh le    Kinh         xem phim    29        Nu
# 11  FSI_11      Luna  Tinh le    Kinh         xem phim    56        Nu
# 12  FSI_12      Long  Tinh le    Kinh          Da bong    21       Nam
# 13  FSI_13     Harry   Ha Noi    Kinh           Cau ca    23        Nu
# 14  FSI_14       Nam  Tinh le    Kinh        Nghe nhac    51       Nam
# 15  FSI_15     Harry  Tinh le    Kinh         xem phim    21       Nam
# 16  FSI_16       Lan  Tinh le    Kinh         Cau long    22        Nu
# 17  FSI_17      Long  Tinh le    Kinh              Gym    31        Nu
# 18  FSI_18       Ron  Tinh le    Kinh             Yoga    30        Nu
# 19  FSI_19      Long  Tinh le    Kinh             Yoga    19       Nam
# 20  FSI_20     Harry  Tinh le    Kinh        Nghe nhac    43       Nam
# 21  FSI_21      Luna  Tinh le    Kinh             Yoga    29        Nu
# 22  FSI_22      Long  Tinh le    Kinh             Yoga    19        Nu
# 23  FSI_23  Hermione  Tinh le    Kinh        Nghe nhac    29       Nam
# 24  FSI_24       Lan  Tinh le    Kinh          Da bong    29        Nu
# 25  FSI_25      Luna  Tinh le     Ede        Nghe nhac    52        Nu
# 26  FSI_26  Hermione  Tinh le    Nung         xem phim    39       Nam
# 27  FSI_27       Nam  Tinh le    Kinh           Cau ca    22       Nam
# 28  FSI_28      Luna  Tinh le    Kinh              Gym    20        Nu
# 29  FSI_29  Hermione  Tinh le    Thai         xem phim    21        Nu
# ..     ...       ...      ...     ...              ...   ...       ...
# 70  FSI_70  Hermione  Tinh le    Kinh         Cau long    23       Nam
# 71  FSI_71       Ron   Ha Noi    Kinh        Nghe nhac    26        Nu
# 72  FSI_72  Hermione   Ha Noi    Kinh        Nghe nhac    23        Nu
# 73  FSI_73      Long  Tinh le    Kinh         xem phim    21       Nam
# 74  FSI_74  Hermione  Tinh le     Ede             Yoga    24       Nam
# 75  FSI_75      Ngoc  Tinh le     Tay         Cau long    29        Nu
# 76  FSI_76      Ngoc  Tinh le    Kinh              Gym    32       Nam
# 77  FSI_77       Lan  Tinh le    Kinh          Da bong    25       Nam
# 78  FSI_78  Hermione   Ha Noi    Kinh         Cau long    24       Nam
# 79  FSI_79       Ron  Tinh le    Kinh             Yoga    23        Nu
# 80  FSI_80      Long  Tinh le    Kinh           Cau ca    36        Nu
# 81  FSI_81      Ngoc  Tinh le    Kinh           Cau ca    21        Nu
# 82  FSI_82     Harry  Tinh le    Kinh        Nghe nhac    27        Nu
# 83  FSI_83      Long   Ha Noi    Kinh              Gym    21       Nam
# 84  FSI_84     Harry  Tinh le     Dao           Cau ca    32       Nam
# 85  FSI_85      Ngoc  Tinh le    Kinh        Nghe nhac    27       Nam
# 86  FSI_86       Lan  Tinh le    Kinh        Nghe nhac    23        Nu
# 87  FSI_87       Nam  Tinh le    Kinh              Gym    32        Nu
# 88  FSI_88      Luna  Tinh le    Kinh              Gym    27       Nam
# 89  FSI_89     Harry  Tinh le    Kinh              Gym    48       Nam
# 90  FSI_90  Hermione  Tinh le    Kinh              Gym    37       Nam
# 91  FSI_91     Harry  Tinh le    Kinh              Gym    34        Nu
# 92  FSI_92       Lan   Ha Noi    Kinh         xem phim    52        Nu
# 93  FSI_93     Harry   Ha Noi    Kinh             Yoga    22       Nam
# 94  FSI_94      Ngoc  Tinh le    Kinh         xem phim    20        Nu
# 95  FSI_95     Harry  Tinh le    Kinh              Gym    28       Nam
# 96  FSI_96       Nam  Tinh le    Kinh           Cau ca    23       Nam
# 97  FSI_97     Harry   Ha Noi    Kinh             Yoga    29       Nam
# 98  FSI_98      Luna   Ha Noi    Kinh             Yoga    34       Nam
# 99  FSI_99      Long  Tinh le    Kinh        Nghe nhac    23       Nam
#
#           Ngoai_ngu Y_thuc_trach_nhiem Hot_work  ...   Nam_kinh_nghiem  \
# 0   Khong chung chi                  D        A  ...                15
# 1   Tieng anh toiec                  B        D  ...                 2
# 2   Khong chung chi                  A        D  ...                 0
# 3   Tieng anh toiec                  C        D  ...                 1
# 4   Khong chung chi                  C        B  ...                 0
# 5   Khong chung chi                  C        D  ...                 5
# 6   Tieng anh toiec                  C        B  ...                 0
# 7   Khong chung chi                  A        D  ...                16
# 8   Khong chung chi                  A        D  ...                 1
# 9   Tieng anh toiec                  A        D  ...                 1
# 10  Khong chung chi                  B        D  ...                10
# 11  Khong chung chi                  B        D  ...                17
# 12  Tieng anh toiec                  A        D  ...                 0
# 13  Khong chung chi                  A        D  ...                 3
# 14  Khong chung chi                  D        D  ...                18
# 15  Khong chung chi                  D        D  ...                 0
# 16  Khong chung chi                  A        B  ...                 0
# 17  Tieng anh toiec                  C        D  ...                11
# 18  Tieng anh toiec                  C        A  ...                 4
# 19  Khong chung chi                  A        D  ...                 0
# 20        Tieng Nga                  A        A  ...                 9
# 21  Tieng anh ielts                  D        D  ...                 3
# 22  Khong chung chi                  C        A  ...                 0
# 23  Khong chung chi                  C        D  ...                 4
# 24  Tieng anh toiec                  C        C  ...                 1
# 25  Tieng anh toiec                  A        D  ...                22
# 26  Tieng anh toiec                  D        C  ...                11
# 27  Khong chung chi                  C        A  ...                 0
# 28  Khong chung chi                  D        A  ...                 0
# 29  Khong chung chi                  B        B  ...                 0
# ..              ...                ...      ...  ...               ...
# 70  Tieng anh toiec                  D        C  ...                 3
# 71  Tieng anh toiec                  B        D  ...                 2
# 72  Khong chung chi                  A        B  ...                 1
# 73  Khong chung chi                  C        B  ...                 2
# 74  Khong chung chi                  D        A  ...                 3
# 75  Tieng anh toiec                  C        D  ...                 8
# 76  Tieng anh toiec                  D        D  ...                 1
# 77  Tieng anh toiec                  B        B  ...                 5
# 78  Khong chung chi                  D        A  ...                 1
# 79  Khong chung chi                  A        A  ...                 1
# 80  Khong chung chi                  D        A  ...                16
# 81  Tieng anh toiec                  D        A  ...                 1
# 82  Tieng anh toiec                  B        B  ...                 3
# 83  Tieng anh ielts                  C        D  ...                 1
# 84       Tieng Phap                  A        A  ...                 7
# 85      Tieng Trung                  B        B  ...                 5
# 86  Tieng anh toiec                  A        B  ...                 3
# 87        Tieng Nga                  D        B  ...                 4
# 88  Khong chung chi                  D        A  ...                 5
# 89  Tieng anh toiec                  D        B  ...                24
# 90  Khong chung chi                  D        A  ...                 9
# 91  Khong chung chi                  D        A  ...                 3
# 92  Khong chung chi                  D        C  ...                10
# 93  Tieng anh toiec                  B        B  ...                 1
# 94  Khong chung chi                  C        C  ...                 0
# 95  Tieng anh toiec                  A        A  ...                 4
# 96  Tieng anh toiec                  C        D  ...                 1
# 97  Tieng anh toiec                  B        B  ...                 6
# 98  Tieng anh ielts                  C        D  ...                11
# 99      Tieng Trung                  D        B  ...                 1
#
#        So_truong            Vi_tri He_so_trach_nhiem         Thanh_tich  \
# 0           Java         Nhan vien               1.0  Khoa hoc sang tao
# 1           None         Nhan vien               1.0               None
# 2           None         Nhan vien               1.0        Oympic toan
# 3           None         Nhan vien               1.0               None
# 4           .NET         Nhan vien               1.0               None
# 5           None         Nhan vien               1.0  Khoa hoc sang tao
# 6         Python         Nhan vien               1.0               None
# 7           None         Nhan vien               1.0               None
# 8           None          Teamlead               1.5               None
# 9           None         Nhan vien               1.0               None
# 10          None         Nhan vien               1.0               None
# 11          None         Nhan vien               1.0               None
# 12          None         Nhan vien               1.0               None
# 13          None          Teamlead               1.5               None
# 14          None  Technical leader               1.0               None
# 15          None         Nhan vien               1.0               None
# 16  Data Science         Nhan vien               1.0               None
# 17          None         Nhan vien               1.0               None
# 18           C++         Nhan vien               1.0               None
# 19          None          Teamlead               1.5               None
# 20           ios         Nhan vien               1.0               None
# 21          None         Nhan vien               1.0               None
# 22           C++         Nhan vien               1.0               None
# 23          None         Nhan vien               1.0               None
# 24           PHP         Nhan vien               1.0        olympic tin
# 25          None         Nhan vien               1.0  Khoa hoc sang tao
# 26           PHP         Nhan vien               1.0               None
# 27           ios         Nhan vien               1.0               None
# 28          Java         Nhan vien               1.0               None
# 29          Ruby         Nhan vien               1.0               None
# ..           ...               ...               ...                ...
# 70           PHP         Nhan vien               1.0        olympic tin
# 71          None         Nhan vien               1.0               None
# 72        Python         Nhan vien               1.0               None
# 73  Data Science         Nhan vien               1.0               None
# 74          Java         Nhan vien               1.0  Nhan tai dat viet
# 75          None         Nhan vien               1.0               None
# 76          None         Nhan vien               1.0               None
# 77        Python         Nhan vien               1.0               None
# 78           ios          Teamlead               1.5  Nhan tai dat viet
# 79          Java         Nhan vien               1.0               None
# 80          Java         Nhan vien               1.0               None
# 81           ios         Nhan vien               1.0               None
# 82          Ruby         Nhan vien               1.0  Khoa hoc sang tao
# 83          None         Nhan vien               1.0               None
# 84           ios          Teamlead               1.5               None
# 85        Python         Nhan vien               1.0               None
# 86       Android         Nhan vien               1.0               None
# 87        Python         Nhan vien               1.0               None
# 88           ios         Nhan vien               1.0               None
# 89          .NET         Nhan vien               1.0               None
# 90           C++         Nhan vien               1.0               None
# 91           C++         Nhan vien               1.0               None
# 92           PHP         Nhan vien               1.0               None
# 93       Android          Teamlead               1.5               None
# 94           PHP          Teamlead               1.5               None
# 95          Java         Nhan vien               1.0               None
# 96          None         Nhan vien               1.0               None
# 97           NLP         Nhan vien               1.0        Oympic toan
# 98          None         Nhan vien               1.0               None
# 99        Python          Teamlead               1.5               None
#
#    Nguong_luong Nang_luc_work  Thoi_gian_gan_bo Luong_cu  Luong
# 0            25             A                 2     17.0  19.00
# 1            15             D                 2      4.0   7.10
# 2            30             C                 1     19.0   7.00
# 3            25             C                 0     15.0   7.00
# 4            25             C                 2     18.0   7.00
# 5            30             D                11     28.0   8.50
# 6            25             A                 1      8.0  12.00
# 7            25             B                 2     19.0  16.00
# 8            30             A                 0      6.0  12.00
# 9            15             D                 4     12.0   2.20
# 10           25             C                 0      5.0  14.00
# 11           15             A                 7     15.0  25.00
# 12           30             A                 2     16.0  12.00
# 13           15             A                 1     22.5  18.00
# 14           25             A                11     23.0  30.20
# 15           15             D                 2      7.0   5.00
# 16           25             C                 3     13.0   7.00
# 17           15             D                12      8.0  12.00
# 18           25             C                 3     19.0  10.50
# 19           15             A                 0     19.5  12.00
# 20           25             A                10      4.0  19.00
# 21           25             C                 4     21.0   9.10
# 22           25             A                 1     10.0  12.00
# 23           30             B                 2     24.0  12.50
# 24           25             D                 8      4.0   5.00
# 25           25             B                 2     24.0  16.00
# 26           25             C                14      6.0  14.00
# 27           25             A                 0      7.0  12.00
# 28           25             C                 1     20.0   7.00
# 29           25             C                 0      6.0   7.00
# ..          ...           ...               ...      ...    ...
# 70           25             D                 3     21.0   7.10
# 71           15             B                 1     11.0   7.46
# 72           25             A                 1     17.0  12.00
# 73           25             B                 1     14.0  11.10
# 74           25             D                 2     23.0   7.10
# 75           25             C                 7     14.0  14.00
# 76           25             A                 7     18.0  12.00
# 77           25             C                 1     20.0  10.50
# 78           25             C                 1     30.0   7.00
# 79           25             C                 1      7.0   7.00
# 80           25             D                 9     15.0  12.00
# 81           25             A                 2     10.0  12.00
# 82           25             A                 0     18.0  14.10
# 83           30             C                 0      9.0   7.00
# 84           25             B                 7     16.5  16.00
# 85           25             B                 2     17.0  12.50
# 86           25             B                 3     22.0  11.10
# 87           25             A                 3      6.0  15.50
# 88           25             A                 1     19.0  20.00
# 89           25             D                 2     21.0  12.00
# 90           25             C                 1     12.0  14.00
# 91           25             A                14     18.0  18.00
# 92           25             B                 2     21.0  16.00
# 93           25             D                 0     31.5   5.00
# 94           25             D                 1     18.0   5.00
# 95           25             A                 0     17.0  15.50
# 96           25             B                 2      4.0   9.00
# 97           25             D                 7     21.0  12.00
# 98           30             D                 2     27.0  12.00
# 99           25             B                 1     15.0   9.00
#
# [100 rows x 24 columns]

# %%
# Thống kê cơ bản
calculary_salary.describe()
# Out:
#                Tuoi  Nam_kinh_nghiem  He_so_trach_nhiem  Nguong_luong  \
# count  10000.000000     10000.000000       10000.000000  10000.000000
# mean      28.143800         4.539600           1.110850     23.257000
# std        8.806706         5.652913           0.375035      4.565527
# min       18.000000         0.000000           1.000000     15.000000
# 25%       22.000000         1.000000           1.000000     25.000000
# 50%       26.000000         3.000000           1.000000     25.000000
# 75%       32.000000         6.000000           1.000000     25.000000
# max       59.000000        39.000000           4.000000     30.000000
#
#        Thoi_gian_gan_bo     Luong_cu         Luong
# count      10000.000000  10000.00000  10000.000000
# mean           3.725900     14.98045     12.387010
# std            3.699478      8.64292      6.842766
# min            0.000000      4.00000      2.200000
# 25%            1.000000      9.00000      8.500000
# 50%            3.000000     14.00000     12.000000
# 75%            6.000000     20.00000     15.000000
# max           14.000000    100.00000     95.000000

# %%
# Số lượng giá trị của một trường dữ liệu
calculary_salary['Bang_cap'].value_counts()
# Out:
# Dai hoc           3828
# Cao dang          3825
# Khong bang cap    1552
# Thac si            695
# Tien si            100
# Name: Bang_cap, dtype: int64

# %%
# Vẽ đồ thị xem phân bố các trường dữ liệu
calculary_salary['Vi_tri'].value_counts().plot(kind='bar')
