# %%
# %matplotlib inline
# Khai bao cac thu vien ho tro
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
print("pandas.__version__ = ", pd.__version__)
# Out:
# pandas.__version__ =  0.23.0

# %%
# Tao dataframe
# B1: Dinh nghia cac thuoc tinh tinh luong cho nhan su gom:
# * Cac thuoc tinh khong anh huong luong: ID, họ tên, địa chỉ, dân tộc, so thich khong lien quan cong viec
# * Cac thuoc tinh anh huong luong: 
# 1. Bang cap: Loai bang, xep loai, truong dao tao
# 2. Tuoi
# 3. Gioi tinh
# 4. Muc luong cong ty cu tra
# 5. Mang cong viec
# 6. So nam kinh nghiem
# 7. So truong trong cong viec: C++, .NET,...
# 8. Do hot cua cong viec hien tai: A, B, C, D
# 9. Ngoai ngu: English(ielts), English(toiec), Tieng Nhat, Tieng Trung, Tieng Phap
# 10. Vi tri ung tuyen: Teamlead
# 11. He so trach nhiem
# 12. Giai thuong, thanh tich ca nhan: olympic tin hoc, khoa hoc sang tao,...
# 13. Nguong luong cho cong viec: Vd: 7tr- 20tr
# 14. Xếp loại trình độ (năng lực công việc) : A, B, C, D 
# (thuộc tính này cho sẵn. Nếu tính thì có thể dựa vào lịch sử kết quả công việc đã đảm nhận)
# 15. Ý thức, trách nhiệm với công việc, công ty
# 16. Thời gian đã gắn bó với công ty
# 17. Luong (Bai toan so 2)
# * Note: Các thuộc tính cần động, tích lũy hoặc thay đổi theo thời gian

# * Tạo phân phối chuẩn
mu, sigma = 0, 5 # mean and standard deviation
s = np.random.normal(mu, sigma, 300)

# * old_company
old_company = 15

# B2: Tao cac list
len_list = 1000
len_list *= 10

# 1. ID
ID = []
for i in range(len_list):
    temp = "FSI_" + str(i)
    ID.append(temp)
#print(ID)

# 2. Tên
Name = [random.choice(['Harry', 'Ron', 'Hermione', 'Luna', 'Long', 'Nam', 'Lan', 'Ngoc']) for i in range(len_list)]
#print(Name)

# 3. Địa chỉ
Dia_chi = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Dia_chi.append('Tinh le')
    else:
        Dia_chi.append('Ha Noi')

# 4. Dân tộc
list_dantoc = ['Thai', 'Mong', 'Tay', 'Nung', 'Muong', 'Dao', 'Hoa', 'Khome', 'Ede', 'Cham']
Dan_toc = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Dan_toc.append('Kinh')
    else:
        temp = random.choice(list_dantoc)
        Dan_toc.append(temp)
               
# 5. Sở thích cá nhân
So_thich_ca_nhan = [random.choice(['Nghe nhac', 'xem phim', 'Cau ca', 'Da bong', 'Cau long', 'Gym', 'Yoga']) for i in range(len_list)]
#print(So_thich_ca_nhan)

# 6. Tuổi
Tuoi = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp<=3):
        temp = random.randrange(18, 30, 1)
        Tuoi.append(temp)
    elif(temp>3 and temp<=8):
        temp = random.randrange(30, 40,1)
        Tuoi.append(temp)
    elif(temp>8 and temp<=10):
        temp = random.randrange(40, 50, 1)
        Tuoi.append(temp)
    else:
        temp = random.randrange(50, 60, 1)
        Tuoi.append(temp)

# 7. Giới tính
Gioi_tinh = [random.choice(['Nam', 'Nu']) for i in range(len_list)]

# 8. Chứng chỉ ngoại ngữ
Ngoai_ngu = []
list_language = ['Tieng anh ielts', 'Tieng Nhat', 'Tieng Trung', 'Tieng Phap', 'Tieng Nga']
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 0):
        Ngoai_ngu.append('Khong chung chi')
    elif(temp>0 and temp<=5):
        Ngoai_ngu.append('Tieng anh toiec')
    else:
        temp = random.choice(list_language)
        Ngoai_ngu.append(temp)

        
# 9. Ý thức trách nhiệm với công việc công ty
Y_thuc_trach_nhiem = [random.choice(['A', 'B', 'C', 'D']) for i in range(len_list)]


# 11, 12, 13. Thông tin về bằng cấp
list_bang = ['Khong', 'Dai hoc', 'Thac si', 'Tien si']
list_truong = ['HNUE', 'HUST', 'EPU', 'VNU', 'USTH', 'HAUI', 'UTC', 'TLU']
Bang_cap = []
Xep_loai_bang = []
Truong_dao_tao = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp<=0):
        bang = random.choice(['Dai hoc', 'Cao dang']);
        Bang_cap.append(bang)
    elif(temp>8):
        if(Tuoi[i] > 27 and Ngoai_ngu[i] != 'Khong chung chi'):
            bang = random.choice(['Thac si', 'Tien si'])
            Bang_cap.append(bang)
        else:
            bang = 'Thac si'
            Bang_cap.append(bang)
    else:
        bang = random.choice(['Dai hoc', 'Cao dang', 'Khong bang cap'])
        Bang_cap.append(bang)
        
    # Khong co bang cap, hoac la bang TS se khong co xep loai
    if(bang == 'Khong bang cap' or bang == 'Tien si'):
        Xep_loai_bang.append('Khong xep loai')
    else:
        Xep_loai_bang.append(random.choice(['Trung binh', 'kha', 'Gioi', 'Xuat sac']))
        
        
    if(bang == 'Khong bang cap'):
        Truong_dao_tao.append('Khong di hoc')
    else:
        temp = random.choice(list_truong)
        Truong_dao_tao.append(temp)

        
# 14. Mảng công việc
Mang_cong_viec = []
for i in range(len_list):
    temp = random.choice(s)
    if(Bang_cap[i] == 'Tien si'):
        Mang_cong_viec.append('Ky su R&D')
    else:
        if(temp <= 0):
            Mang_cong_viec.append('Lap trinh vien')
        elif(temp>0 and temp<=5):
            viec = random.choice(['Ky su R&D', 'BA', 'Tu van ban hang'])
            Mang_cong_viec.append(viec)
        else:
            if(Gioi_tinh[i] == 'Nam'):
                Mang_cong_viec.append('PM')
            else:
                viec = random.choice(['Ke toan', 'Tester', 'Xu ly data'])
                Mang_cong_viec.append(viec)
            
            

# 15. Số năm kinh nghiệm
Nam_kinh_nghiem = []
for i in range(len_list):
    temp = Tuoi[i] - 18;
    if(temp > 0):
        kn = random.randrange(0, temp, 1)
        #print('type = ', type(temp))
        Nam_kinh_nghiem.append(kn)
    else:
        Nam_kinh_nghiem.append(0)
    #print('Nam_kinh_nghiem = ', Nam_kinh_nghiem[i])

# 16. Sở trường công việc
So_truong = []
for i in range(len_list):
    if(Mang_cong_viec[i] == 'Lap trinh vien'):
        temp = random.choice(['C++', '.NET', 'Java', 'Android', 'Ruby', 'PHP', 'Python', 'ios'])
        So_truong.append(temp)
    elif(Mang_cong_viec[i] == 'Ky su R&D'):
        temp = random.choice(['Computer vision', 'NLP', 'Data Science', 'Tools'])
        So_truong.append(temp)
    else:
        So_truong.append('None')

# 10. Mức độ hót của công việc hiện tại
Hot_work = []
for i in range(len_list):
    if(So_truong[i] == 'C++' or So_truong[i] == 'Java' or So_truong[i] == 'ios'):
        Hot_work.append('A')
    elif(So_truong[i] == 'PHP'):
        Hot_work.append('C')
    elif(So_truong[i]=='None'):
        Hot_work.append('D')
    else:
        Hot_work.append('B')

# 17. Vị trí ứng tuyển
Vi_tri = []
for i in range(len_list):
    temp = random.choice(s)
    if(temp < 5):
        Vi_tri.append('Nhan vien')
    else:
        if(Nam_kinh_nghiem[i]>8):
            Vi_tri.append(random.choice(['Technical leader', 'Truong phong']))
        else:
            Vi_tri.append('Teamlead')
    

# 18. Hệ số trách nhiệm
He_so_trach_nhiem = []
for i in range(len_list):
    if(Vi_tri[i] == 'Nhan vien'):
        He_so_trach_nhiem.append(1)
    elif(Vi_tri[i] == 'Teamlead'):
        He_so_trach_nhiem.append(1.5)
    elif(Vi_tri[i] == 'Teachnical leader'):
        He_so_trach_nhiem.append(2)
    elif(Vi_tri[i] == 'Truong phong'):
        He_so_trach_nhiem.append(4)
    else:
        He_so_trach_nhiem.append(1)
        
# 19. Giải thưởng, thành tích cá nhân
Thanh_tich = []
list_thanhtich = ['Oympic toan', 'olympic tin', 'Khoa hoc sang tao', 'Nhan tai dat viet', 'None']
for i in range(len_list):
    temp = random.choice(s)
    if(temp <= 5):
        Thanh_tich.append('None')
    else:
        
        if(Bang_cap[i] == 'Khong'):
            Thanh_tich.append('None')
        else:
            temp = random.choice(list_thanhtich)
            Thanh_tich.append(temp)
# 20. Ngưỡng lương
Nguong_luong = []
for i in range(len_list):
    if(Mang_cong_viec[i] == 'PM'):
        Nguong_luong.append(30)
    elif(Mang_cong_viec[i] == 'Lap trinh vien' or Mang_cong_viec[i] == 'Ky su R&D' or Mang_cong_viec[i] == 'BA'):
        Nguong_luong.append(25)
    else:
        Nguong_luong.append(15)
        
# 21. Xep loai trinh do (Nang luc thuc hien cong viec)
Nang_luc_work = []
for i in range(len_list):
    if(Bang_cap[i]=='Thac si' or Bang_cap[i] == 'Tien si' or Vi_tri[i]=='Truong phong' or Vi_tri[i]== 'Technical leader'):
        temp = random.choice(s)
        if(temp < 5):
            Nang_luc_work.append(random.choice(['A']))
        else:
            Nang_luc_work.append(random.choice(['A', 'B']))
    else:
        Nang_luc_work.append(random.choice(['A', 'B', 'C', 'D']))

# 22. Thời gian gắn bó với công ty
Thoi_gian_gan_bo = []
for i in range(len_list):
    temp = random.choice(s)
    time_max = Tuoi[i] - 18
    if(Tuoi[i] <=19):
        if(temp>=0):
            Thoi_gian_gan_bo.append(0)
        else:
            Thoi_gian_gan_bo.append(1)
    else:
        if(time_max >= old_company):
            Thoi_gian_gan_bo.append(random.randrange(0, old_company, 1))
        else:
            Thoi_gian_gan_bo.append(random.randrange(0, time_max, 1))
        
# 23. Lịch sử lương
Luong_cu = []
for i in range(len_list):
    if(Bang_cap[i] == 'Tien si'):
        money_min = 20
    elif(Bang_cap[i] == 'Thac si'):
        money_min = 15
    elif(Bang_cap[i] == 'Dai hoc '):
        money_min = 7
    else:
        money_min = 4
        
    if(money_min < Nguong_luong[i]):
        temp = random.randrange(money_min, Nguong_luong[i], 1) * He_so_trach_nhiem[i]
        Luong_cu.append(temp)
    else:
        temp = money_min * He_so_trach_nhiem[i]
        Luong_cu.append(temp)
    

# 24. Lương
Luong = []
for i in range(len_list):
    temp = Luong_cu[i] * 0.05
    Luong.append(Luong_cu[i] + temp)
        
# B3: Tao dataframe
data = pd.DataFrame()
data['ID'] = ID
data['Name'] = Name
data['Dia_chi'] = Dia_chi
data['Dan_toc'] = Dan_toc
data['So_thich_ca_nhan'] = So_thich_ca_nhan
data['Tuoi'] = Tuoi
data['Gioi_tinh'] = Gioi_tinh
data['Ngoai_ngu'] = Ngoai_ngu
data['Y_thuc_trach_nhiem'] = Y_thuc_trach_nhiem
data['Hot_work'] = Hot_work

data['Bang_cap'] = Bang_cap
data['Xep_loai_bang'] = Xep_loai_bang
data['Truong_dao_tao'] = Truong_dao_tao

data['Mang_cong_viec'] = Mang_cong_viec
data['Nam_kinh_nghiem'] = Nam_kinh_nghiem
data['So_truong'] = So_truong
data['Vi_tri'] = Vi_tri
data['He_so_trach_nhiem'] = He_so_trach_nhiem
data['Thanh_tich'] = Thanh_tich
data['Nguong_luong'] = Nguong_luong
data['Nang_luc_work'] = Nang_luc_work
data['Thoi_gian_gan_bo'] = Thoi_gian_gan_bo
data['Luong_cu'] = Luong_cu

data['Luong'] = Luong

# B4: Luu DataFrame
data.to_csv('data.csv')

print("DONE")
# Out:
# DONE

# %%
# Xem thử 100 bản ghi
data.head(100)
# Out:
#         ID      Name  Dia_chi Dan_toc So_thich_ca_nhan  Tuoi Gioi_tinh  \
# 0    FSI_0      Ngoc  Tinh le    Kinh         xem phim    31       Nam
# 1    FSI_1       Ron  Tinh le     Dao         Cau long    18       Nam
# 2    FSI_2       Ron  Tinh le    Kinh             Yoga    23        Nu
# 3    FSI_3  Hermione  Tinh le    Kinh        Nghe nhac    22        Nu
# 4    FSI_4     Harry  Tinh le    Kinh        Nghe nhac    38        Nu
# 5    FSI_5       Nam  Tinh le    Kinh           Cau ca    52       Nam
# 6    FSI_6       Ron  Tinh le    Nung        Nghe nhac    18        Nu
# 7    FSI_7      Luna  Tinh le    Kinh          Da bong    37        Nu
# 8    FSI_8       Ron  Tinh le    Kinh         xem phim    20        Nu
# 9    FSI_9       Ron  Tinh le    Kinh             Yoga    29       Nam
# 10  FSI_10      Ngoc  Tinh le    Kinh             Yoga    18       Nam
# 11  FSI_11       Nam  Tinh le    Kinh             Yoga    24       Nam
# 12  FSI_12      Luna  Tinh le    Kinh              Gym    26       Nam
# 13  FSI_13      Luna  Tinh le    Kinh          Da bong    44        Nu
# 14  FSI_14      Ngoc  Tinh le    Kinh           Cau ca    20        Nu
# 15  FSI_15       Ron  Tinh le    Mong           Cau ca    29       Nam
# 16  FSI_16       Lan  Tinh le    Kinh         xem phim    29       Nam
# 17  FSI_17      Luna  Tinh le    Kinh              Gym    32       Nam
# 18  FSI_18      Long   Ha Noi    Kinh             Yoga    32       Nam
# 19  FSI_19       Nam  Tinh le    Kinh         Cau long    26        Nu
# 20  FSI_20       Ron   Ha Noi     Ede         xem phim    35        Nu
# 21  FSI_21       Lan  Tinh le    Kinh          Da bong    20       Nam
# 22  FSI_22      Luna  Tinh le    Kinh        Nghe nhac    28       Nam
# 23  FSI_23  Hermione  Tinh le    Nung          Da bong    29        Nu
# 24  FSI_24      Long  Tinh le    Kinh         Cau long    23        Nu
# 25  FSI_25       Lan  Tinh le    Kinh              Gym    20        Nu
# 26  FSI_26       Nam  Tinh le    Kinh              Gym    27       Nam
# 27  FSI_27       Ron  Tinh le    Cham           Cau ca    30       Nam
# 28  FSI_28      Luna  Tinh le    Kinh              Gym    18       Nam
# 29  FSI_29      Long   Ha Noi    Kinh         xem phim    25       Nam
# ..     ...       ...      ...     ...              ...   ...       ...
# 70  FSI_70     Harry  Tinh le    Kinh         xem phim    30       Nam
# 71  FSI_71      Ngoc  Tinh le    Kinh         Cau long    26        Nu
# 72  FSI_72      Long  Tinh le    Kinh         xem phim    37       Nam
# 73  FSI_73  Hermione   Ha Noi    Kinh              Gym    38       Nam
# 74  FSI_74     Harry  Tinh le    Kinh          Da bong    27       Nam
# 75  FSI_75       Nam  Tinh le    Kinh              Gym    27        Nu
# 76  FSI_76      Ngoc  Tinh le    Cham          Da bong    23        Nu
# 77  FSI_77  Hermione  Tinh le   Khome             Yoga    18        Nu
# 78  FSI_78  Hermione  Tinh le    Kinh         Cau long    18       Nam
# 79  FSI_79      Ngoc   Ha Noi    Kinh         Cau long    18       Nam
# 80  FSI_80      Ngoc  Tinh le    Kinh           Cau ca    25       Nam
# 81  FSI_81       Lan  Tinh le    Kinh          Da bong    29        Nu
# 82  FSI_82       Nam  Tinh le    Kinh         Cau long    29       Nam
# 83  FSI_83       Nam  Tinh le    Kinh           Cau ca    29       Nam
# 84  FSI_84     Harry  Tinh le    Kinh           Cau ca    39        Nu
# 85  FSI_85       Nam  Tinh le   Muong              Gym    50       Nam
# 86  FSI_86      Ngoc  Tinh le    Kinh              Gym    37        Nu
# 87  FSI_87      Long  Tinh le    Kinh        Nghe nhac    19        Nu
# 88  FSI_88     Harry  Tinh le     Hoa        Nghe nhac    30       Nam
# 89  FSI_89      Ngoc   Ha Noi   Khome         Cau long    19       Nam
# 90  FSI_90       Lan  Tinh le    Nung             Yoga    21        Nu
# 91  FSI_91      Luna  Tinh le    Kinh         Cau long    24       Nam
# 92  FSI_92      Ngoc  Tinh le    Kinh         Cau long    51        Nu
# 93  FSI_93      Long  Tinh le    Thai           Cau ca    28       Nam
# 94  FSI_94      Ngoc  Tinh le    Kinh        Nghe nhac    23       Nam
# 95  FSI_95      Long  Tinh le    Kinh             Yoga    40        Nu
# 96  FSI_96     Harry  Tinh le    Kinh             Yoga    19       Nam
# 97  FSI_97       Ron  Tinh le    Kinh         Cau long    20       Nam
# 98  FSI_98     Harry  Tinh le    Kinh           Cau ca    20        Nu
# 99  FSI_99     Harry  Tinh le    Kinh          Da bong    23       Nam
#
#           Ngoai_ngu Y_thuc_trach_nhiem Hot_work  ...   Nam_kinh_nghiem  \
# 0   Khong chung chi                  D        B  ...                12
# 1   Tieng anh toiec                  C        D  ...                 0
# 2        Tieng Phap                  D        D  ...                 4
# 3   Tieng anh toiec                  A        B  ...                 3
# 4       Tieng Trung                  C        A  ...                 8
# 5   Khong chung chi                  D        A  ...                28
# 6        Tieng Phap                  A        D  ...                 0
# 7   Tieng anh toiec                  D        A  ...                 4
# 8        Tieng Phap                  A        A  ...                 1
# 9        Tieng Nhat                  B        D  ...                 2
# 10  Khong chung chi                  C        D  ...                 0
# 11  Khong chung chi                  C        D  ...                 1
# 12       Tieng Phap                  A        B  ...                 7
# 13  Tieng anh toiec                  A        D  ...                23
# 14  Khong chung chi                  D        D  ...                 1
# 15  Tieng anh toiec                  C        B  ...                 6
# 16  Tieng anh toiec                  A        D  ...                 9
# 17  Tieng anh toiec                  A        B  ...                 4
# 18  Tieng anh toiec                  D        C  ...                 5
# 19  Tieng anh toiec                  B        B  ...                 3
# 20  Khong chung chi                  B        C  ...                 4
# 21  Khong chung chi                  C        B  ...                 0
# 22  Tieng anh toiec                  A        B  ...                 3
# 23  Tieng anh toiec                  C        B  ...                 3
# 24  Khong chung chi                  B        B  ...                 1
# 25  Khong chung chi                  C        D  ...                 0
# 26  Tieng anh toiec                  D        B  ...                 6
# 27  Tieng anh toiec                  A        B  ...                 3
# 28  Khong chung chi                  A        A  ...                 0
# 29  Tieng anh toiec                  D        D  ...                 4
# ..              ...                ...      ...  ...               ...
# 70  Khong chung chi                  D        D  ...                 3
# 71  Tieng anh toiec                  D        B  ...                 4
# 72  Tieng anh toiec                  B        B  ...                 1
# 73       Tieng Phap                  C        D  ...                 1
# 74  Khong chung chi                  C        D  ...                 4
# 75  Tieng anh toiec                  A        D  ...                 8
# 76  Tieng anh toiec                  D        A  ...                 1
# 77       Tieng Phap                  D        D  ...                 0
# 78  Khong chung chi                  D        D  ...                 0
# 79  Tieng anh toiec                  A        D  ...                 0
# 80  Tieng anh ielts                  B        B  ...                 6
# 81  Tieng anh toiec                  D        D  ...                 0
# 82  Tieng anh toiec                  B        B  ...                 3
# 83  Tieng anh toiec                  C        D  ...                 3
# 84      Tieng Trung                  A        B  ...                20
# 85  Khong chung chi                  B        B  ...                25
# 86  Khong chung chi                  D        D  ...                 7
# 87  Tieng anh toiec                  D        B  ...                 0
# 88  Khong chung chi                  D        B  ...                 8
# 89  Khong chung chi                  D        B  ...                 0
# 90       Tieng Nhat                  C        B  ...                 0
# 91  Khong chung chi                  A        A  ...                 0
# 92  Tieng anh toiec                  A        B  ...                32
# 93  Khong chung chi                  D        B  ...                 4
# 94  Tieng anh toiec                  B        B  ...                 4
# 95        Tieng Nga                  D        A  ...                14
# 96  Tieng anh toiec                  B        B  ...                 0
# 97  Tieng anh toiec                  D        A  ...                 0
# 98  Tieng anh toiec                  C        B  ...                 1
# 99  Khong chung chi                  D        D  ...                 0
#
#           So_truong            Vi_tri He_so_trach_nhiem         Thanh_tich  \
# 0              Ruby      Truong phong               4.0               None
# 1              None         Nhan vien               1.0               None
# 2              None         Nhan vien               1.0               None
# 3              Ruby         Nhan vien               1.0               None
# 4               ios         Nhan vien               1.0               None
# 5               ios         Nhan vien               1.0               None
# 6              None         Nhan vien               1.0               None
# 7               ios         Nhan vien               1.0               None
# 8               ios         Nhan vien               1.0        Oympic toan
# 9              None         Nhan vien               1.0               None
# 10             None         Nhan vien               1.0               None
# 11             None          Teamlead               1.5  Khoa hoc sang tao
# 12             Ruby         Nhan vien               1.0               None
# 13             None         Nhan vien               1.0               None
# 14             None         Nhan vien               1.0               None
# 15            Tools         Nhan vien               1.0               None
# 16             None         Nhan vien               1.0  Khoa hoc sang tao
# 17          Android         Nhan vien               1.0               None
# 18              PHP         Nhan vien               1.0               None
# 19          Android         Nhan vien               1.0        olympic tin
# 20              PHP         Nhan vien               1.0               None
# 21          Android         Nhan vien               1.0               None
# 22          Android         Nhan vien               1.0               None
# 23             Ruby         Nhan vien               1.0               None
# 24           Python          Teamlead               1.5               None
# 25             None         Nhan vien               1.0        Oympic toan
# 26           Python         Nhan vien               1.0               None
# 27     Data Science         Nhan vien               1.0               None
# 28              C++         Nhan vien               1.0               None
# 29             None         Nhan vien               1.0               None
# ..              ...               ...               ...                ...
# 70             None         Nhan vien               1.0               None
# 71            Tools         Nhan vien               1.0               None
# 72           Python         Nhan vien               1.0               None
# 73             None         Nhan vien               1.0               None
# 74             None         Nhan vien               1.0               None
# 75             None         Nhan vien               1.0               None
# 76             Java         Nhan vien               1.0               None
# 77             None         Nhan vien               1.0               None
# 78             None          Teamlead               1.5               None
# 79             None         Nhan vien               1.0               None
# 80  Computer vision         Nhan vien               1.0               None
# 81             None         Nhan vien               1.0               None
# 82              NLP         Nhan vien               1.0               None
# 83             None         Nhan vien               1.0               None
# 84           Python  Technical leader               1.0               None
# 85             .NET         Nhan vien               1.0        Oympic toan
# 86             None         Nhan vien               1.0               None
# 87              NLP         Nhan vien               1.0               None
# 88           Python         Nhan vien               1.0               None
# 89           Python         Nhan vien               1.0               None
# 90          Android         Nhan vien               1.0  Khoa hoc sang tao
# 91              C++         Nhan vien               1.0               None
# 92           Python         Nhan vien               1.0               None
# 93             .NET         Nhan vien               1.0  Khoa hoc sang tao
# 94              NLP         Nhan vien               1.0               None
# 95             Java         Nhan vien               1.0               None
# 96           Python          Teamlead               1.5  Khoa hoc sang tao
# 97              ios         Nhan vien               1.0               None
# 98              NLP         Nhan vien               1.0               None
# 99             None         Nhan vien               1.0               None
#
#    Nguong_luong Nang_luc_work  Thoi_gian_gan_bo Luong_cu  Luong
# 0            25             A                 0     56.0  58.80
# 1            30             A                 1     29.0  30.45
# 2            15             A                 2      8.0   8.40
# 3            25             B                 1     14.0  14.70
# 4            25             D                 1     17.0  17.85
# 5            25             A                13     16.0  16.80
# 6            15             B                 0      8.0   8.40
# 7            25             C                 4     11.0  11.55
# 8            25             C                 1     15.0  15.75
# 9            15             D                 3      7.0   7.35
# 10           15             B                 0      4.0   4.20
# 11           25             A                 5     24.0  25.20
# 12           25             C                 6      8.0   8.40
# 13           15             A                14      7.0   7.35
# 14           15             A                 0     14.0  14.70
# 15           25             A                 2     18.0  18.90
# 16           25             A                10      5.0   5.25
# 17           25             D                 2     17.0  17.85
# 18           25             D                12     17.0  17.85
# 19           25             C                 4     15.0  15.75
# 20           25             C                 6      9.0   9.45
# 21           25             A                 1     22.0  23.10
# 22           25             B                 5     20.0  21.00
# 23           25             B                 1     12.0  12.60
# 24           25             C                 1     24.0  25.20
# 25           15             C                 1     12.0  12.60
# 26           25             C                 1     14.0  14.70
# 27           25             A                10     14.0  14.70
# 28           25             B                 1     12.0  12.60
# 29           30             C                 3     22.0  23.10
# ..          ...           ...               ...      ...    ...
# 70           25             A                 3     22.0  23.10
# 71           25             A                 2     13.0  13.65
# 72           25             B                 1     15.0  15.75
# 73           15             D                 9     11.0  11.55
# 74           15             A                 4     12.0  12.60
# 75           15             A                 3     10.0  10.50
# 76           25             B                 3     22.0  23.10
# 77           15             A                 1     15.0  15.75
# 78           25             A                 1      9.0   9.45
# 79           30             C                 1     26.0  27.30
# 80           25             B                 0     16.0  16.80
# 81           15             D                 6      8.0   8.40
# 82           25             A                10     20.0  21.00
# 83           30             D                 7     17.0  17.85
# 84           25             A                 3     15.0  15.75
# 85           25             B                 9      8.0   8.40
# 86           25             B                14     13.0  13.65
# 87           25             A                 0     14.0  14.70
# 88           25             D                 7     10.0  10.50
# 89           25             D                 1      6.0   6.30
# 90           25             B                 0      6.0   6.30
# 91           25             B                 0     11.0  11.55
# 92           25             A                 7     18.0  18.90
# 93           25             B                 1     21.0  22.05
# 94           25             B                 4     15.0  15.75
# 95           25             D                 9     19.0  19.95
# 96           25             B                 1      6.0   6.30
# 97           25             A                 0     18.0  18.90
# 98           25             A                 0     18.0  18.90
# 99           25             D                 0     21.0  22.05
#
# [100 rows x 24 columns]

# %%
# Thống kê cơ bản
data.describe()
# Out:
#                Tuoi  Nam_kinh_nghiem  He_so_trach_nhiem  Nguong_luong  \
# count  10000.000000     10000.000000       10000.000000  10000.000000
# mean      27.403400         4.200700           1.098300     23.393500
# std        7.766602         5.185837           0.348209      4.338034
# min       18.000000         0.000000           1.000000     15.000000
# 25%       22.000000         0.000000           1.000000     25.000000
# 50%       26.000000         2.000000           1.000000     25.000000
# 75%       31.000000         6.000000           1.000000     25.000000
# max       59.000000        39.000000           4.000000     30.000000
#
#        Thoi_gian_gan_bo      Luong_cu         Luong
# count       10000.00000  10000.000000  10000.000000
# mean            3.60550     14.811650     15.552232
# std             3.61892      8.416735      8.837572
# min             0.00000      4.000000      4.200000
# 25%             1.00000      9.000000      9.450000
# 50%             2.00000     14.000000     14.700000
# 75%             6.00000     20.000000     21.000000
# max            14.00000     96.000000    100.800000

# %%
# Số lượng giá trị của một trường dữ liệu
data['Bang_cap'].value_counts()
# Out:
# Dai hoc           3966
# Cao dang          3913
# Khong bang cap    1503
# Thac si            555
# Tien si             63
# Name: Bang_cap, dtype: int64

# %%
# Vẽ đồ thị xem phân bố các trường dữ liệu
data['Bang_cap'].value_counts().plot(kind='bar')
